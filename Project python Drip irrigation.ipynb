# %%
from IPython.display import display
from getpass import getpass
from tabulate import tabulate
import pandas as pd
import psycopg2
import psycopg2.extras
conn = psycopg2.connect(
       database = "",
       user = "postgres",
       password = "1723",
       host = "localhost",
       port = "5432")

w = conn.cursor(cursor_factory= psycopg2.extras.DictCursor)  

table = '''CREATE TABLE IF NOT EXISTS ORDER_1 (
           NAME CHAR(20) NOT NULL,
           MOBILE_NO VARCHAR(10) NOT NULL,
           ADDRESS VARCHAR NOT NULL,
           CROP CHAR(15) NOT NULL,
           AREA FLOAT NOT NULL
)'''
w.execute(table)
conn.commit()

def registration():
    
 while True: 
        NAME = input("Enter Your Name: ")
        MOBILE_NO = input("Mobile No.: ")
        ADDRESS = input("Address(Village/Taluka/Dist.): ")
        CROP = input("Select the Crop ( Papaya/ Pomogranet/ Custard Apple/ Dragon Fruit): ")
        AREA = float(input("Area under which drip has to be installed (Acres): "))
    
        if len(MOBILE_NO) == 10 and AREA > .5: 
            query_1= ("insert into order_1 values('{}',{},'{}','{}',{})".format(NAME,MOBILE_NO,ADDRESS,CROP,AREA))
            w.execute(query_1)
            conn.commit()
            print(" ")
            print("        **Your request is accepted, Soon our Field Executive will contact you**")
            print(" ")
            print(" ")
    
            print('''
            To View general water management guide PRESS "1" else press any key''')
    
            press = int(input("-->  "))
    
            if press == 1 and CROP.lower() == 'papaya':
                papaya = open("C:\\Users\\Abhimanyu Gupta\\Downloads\\Papaya.txt","rt")
                print(papaya.readlines())
                
        
            elif press == 1 and CROP.lower() == 'dragonfruit':
                Dragonfruit = open("C:\\Users\\Abhimanyu Gupta\\Downloads\\Dragonfruit.txt","rt")
                print(Dragonfruit.readlines())
                
        
            elif press == 1 and CROP.lower() == 'custard apple':
                custard = open("C:\\Users\\Abhimanyu Gupta\\Downloads\\casturd apple.txt","rt")
                print(custard.readlines())
               
        
            elif press == 1 and CROP.lower() == 'pomogranet':
                pomogranet = open("C:\\Users\\Abhimanyu Gupta\\Downloads\\pomogranet.txt","rt")
                print(pomogranet.readlines())
                print(" ")
                print('''Do You want to see our main menu : 
                   If Yes Press "1"
                   If No Press any other key''')
            
                option = int(input("---> "))
                if option == 1:
                    Main_menu()
                else:
                    print(" ")
                    print("Thankyou for using our portal")
                    break 
        else:
            print("Enter Valid input !!!")
            
            
def drip():
 state_list = ['gujarat','maharashtra']
 fruit = ["papaya","custard apple","pomogranet","dragonfruit"]
 while True: 
        area = float(input("Area(acres): "))
        crop_name = input("Select the Crop ( Papaya/ Pomogranet/ Custard Apple/ Dragon Fruit): ")
        state = input("Enter your State (Gujarat/Maharashtra): ")
        if area > .5 and state.lower() in state_list and crop_name.lower() in fruit:
            #papaya
            if state.lower() == 'gujarat' and crop_name.lower() == 'papaya':
                subsidy = 50
                cost = area*45000
                cost_final = cost*(1-.5)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_a = ['Area',area]
                list_b = ['Crop Name', crop_name]
                list_c = ['Cost/ acer', 45000]        
                list_d = ['Base Fare',cost_exc]        
                list_e = ['CGST', cgst]       
                list_f = ['SGST', sgst]      
                list_g = ['State Subsidy(%)',subsidy]      
                list_h = ['Final Cost', cost_final] 
        
                list_q = [list_a,list_b,list_c,list_d,list_e,list_f,list_g,list_h]
                print(tabulate(list_q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")

        
            #dragonfruit
            elif state.lower() == 'gujarat' and crop_name.lower() == 'dragonfruit':
                subsidy = 50
                cost = area*60000
                cost_final = cost*(1-.5)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_1a = ['Area',area]
                list_1b = ['Crop Name', crop_name]
                list_1c = ['Cost/ acer', 60000]        
                list_1d = ['Base Fare',cost_exc]        
                list_1e = ['CGST', cgst]       
                list_1f = ['SGST', sgst]      
                list_1g = ['State Subsidy(%)',subsidy]      
                list_1h = ['Final Cost', cost_final] 
        
                list_1q = [list_1a,list_1b,list_1c,list_1d,list_1e,list_1f,list_1g,list_1h]
                print(tabulate(list_1q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")
        
            #custurd apple
            elif state.lower() == 'gujarat' and crop_name.lower() == 'casturd apple':
                subsidy = 50
                cost = area*40000
                cost_final = cost*(1-.5)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_2a = ['Area',area]
                list_2b = ['Crop Name', crop_name]
                list_2c = ['Cost/ acer', 40000]        
                list_2d = ['Base Fare',cost_exc]        
                list_2e = ['CGST', cgst]       
                list_2f = ['SGST', sgst]      
                list_2g = ['State Subsidy(%)',subsidy]      
                list_2h = ['Final Cost', cost_final] 
        
                list_2q = [list_2a,list_2b,list_2c,list_2d,list_2e,list_2f,list_2g,list_2h]
                print(tabulate(list_2q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")
    
    
             #pomogranet     
            elif state.lower() == 'gujarat' and crop_name.lower() == 'pomogranet':
                subsidy = 50
                cost = area*50000
                cost_final = cost*(1-.5)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_3a = ['Area',area]
                list_3b = ['Crop Name', crop_name]
                list_3c = ['Cost/ acer', 50000]        
                list_3d = ['Base Fare',cost_exc]        
                list_3e = ['CGST', cgst]       
                list_3f = ['SGST', sgst]      
                list_3g = ['State Subsidy(%)',subsidy]      
                list_3h = ['Final Cost', cost_final] 
        
                list_3q = [list_3a,list_3b,list_3c,list_3d,list_3e,list_3f,list_3g,list_3h]
                print(tabulate(list_3q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")
    
            #dragonfruit MH
            elif state.lower() == 'maharashtra' and crop_name.lower() == 'dragonfruit':
                subsidy = 45
                cost = area*54000
                cost_final = cost*(1-.45)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_4a = ['Area',area]
                list_4b = ['Crop Name', crop_name]
                list_4c = ['Cost/ acer', 54000]        
                list_4d = ['Base Fare',cost_exc]        
                list_4e = ['CGST', cgst]       
                list_4f = ['SGST', sgst]      
                list_4g = ['State Subsidy(%)',subsidy]      
                list_4h = ['Final Cost', cost_final] 
        
                list_4q = [list_4a,list_4b,list_4c,list_4d,list_4e,list_4f,list_4g,list_4h]
                print(tabulate(list_4q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")
        
            #papaya MH
            elif state.lower() == 'maharahstra' and crop_name.lower() == 'papaya':
                subsidy = 45
                cost = area*50000
                cost_final = cost*(1-.45)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_5a = ['Area',area]
                list_5b = ['Crop Name', crop_name]
                list_5c = ['Cost/ acer', 50000]        
                list_5d = ['Base Fare',cost_exc]        
                list_5e = ['CGST', cgst]       
                list_5f = ['SGST', sgst]      
                list_5g = ['State Subsidy(%)',subsidy]      
                list_5h = ['Final Cost', cost_final] 
        
                list_5q = [list_5a,list_5b,list_5c,list_5d,list_5e,list_5f,list_5g,list_5h]
                print(tabulate(list_5q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")
        
            #pomogranet MH
            elif state.lower() == 'maharashtra' and crop_name.lower() == 'pomogranet':
                subsidy = .45
                cost = area*60000
                cost_final = cost*(1-.45)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_6a = ['Area',area]
                list_6b = ['Crop Name', crop_name]
                list_6c = ['Cost/ acer', 60000]        
                list_6d = ['Base Fare',cost_exc]        
                list_6e = ['CGST', cgst]       
                list_6f = ['SGST', sgst]      
                list_6g = ['State Subsidy(%)',subsidy]      
                list_6h = ['Final Cost', cost_final] 
        
                list_6q = [list_6a,list_6b,list_6c,list_6d,list_6e,list_6f,list_6g,list_6h]
                print(tabulate(list_6q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")
        
     
            #caster apple MH
            elif state.lower() == 'maharashtra' and crop_name.lower() == 'caster apple':
                subsidy = 45
                cost = area*55000
                cost_final = cost*(1-.45)
                cgst = .06*cost
                sgst = .06*cost
                cost_exc = cost-(cgst+sgst)
                list_7a = ['Area',area]
                list_7b = ['Crop Name', crop_name]
                list_7c = ['Cost/ acer', 55000]        
                list_7d = ['Base Fare',cost_exc]        
                list_7e = ['CGST', cgst]       
                list_7f = ['SGST', sgst]      
                list_7g = ['State Subsidy(%)',subsidy]      
                list_7h = ['Final Cost', cost_final] 
        
                list_7q = [list_7a,list_7b,list_7c,list_7d,list_7e,list_7f,list_7g,list_7h]
                print(tabulate(list_7q, tablefmt="grid"))
                print("Total installation cost may vary a little bit according to the field condition and plant spacing")
            print(" ")
            print('''Do You want to see our INVENTORY MENU: 
                   If Yes Press "1"
                   If No Press any other key''')
            option = int(input("---> "))
            if option == 1:
                inventory()
                break
            else:
                print(" ")
                print("Thankyou for using our portal")
                break
        else:
         print("Enter the valid input !!!")


        


def inventory():
     print("*****INVENTORY MENU*****")
     print("")
     print("1.Dripper--->Rs10","2.Main Line--->Rs11/meter","3.Sub Main--->Rs25/meter","4.Tank(1000 liters)--->Rs5000","5.Valve--->Rs80","6.Exit")
     while True:
        
        c=int(input("Enter your choice:"))
        d=int(input("Enter the quantity:"))
        if (c==1):
            c1=10*d
            print("Total amount is:",c1)
            
        elif (c==2):
            c2=11*d
            print("Total amount is: Rs",c2)
            
        elif (c==3):
            c3=25*d
            print("Total amount is: Rs",c3)
              
        elif (c==4):
            c4=5000*d
            print("Total amount is: Rs",c4)
             
        elif (c==5):
            c5=80*d
            print("Total amount is: Rs",c5)
             
        else:
            print("Enter Valid input !!!")
            
            
            print(" ")
        print('''Do You want to purchase our products : 
                   If Yes Press "1"
                   If No Press any other key''')
            
        option = int(input("---> "))
        if option == 1:
            registration()
            break
        else:
            print(" ")
            print("Thankyou for using our portal")
            break 
        
    
            
                

            
            
            
def admin():
    while True:
        password = getpass("Enter your Password: ")
        pas = 'admin1234'
        if password == pas:
            print("----Welcome Admin----")
            print(" ")
            print("Get assess to Field visit database PRESS 1")
            print("To Logout PRESS any other key")
            press = int(input('--> '))
            if press == 1:
                w.execute("select NAME,MOBILE_NO,ADDRESS,CROP,AREA from order_1;")
                abc=w.fetchall()
                conn.commit()
                
                l1=[]
                l2=[]
                l3=[]
                l4=[]
                l5=[]
                for i in range(len(abc)):
                    l1.append(abc[i][0])
                    l2.append(abc[i][1])
                    l3.append(abc[i][2])
                    l4.append(abc[i][3])
                    l5.append(abc[i][4])
                dict_cust={'NAME':l1,'MOBILE_NO':l2,'ADDRESS':l3,'CROP':l4,'AREA':l5}
                headers=['NAME','MOBILE_NO','ADDRESS','CROP','AREA']
                print(tabulate(dict_cust, headers, tablefmt="grid"))
                
                print(" ")
                print('''Do You want to see our main menu : 
                   If Yes Press "1"
                   If No Press any other key''')
            
                option = int(input("---> "))
                if option == 1:
                    Main_menu()
                else:
                    print(" ")
                    print("Thankyou for using our portal")
                    break 
        else: 
            print("Enter the correct password !!!")
            
            
            
def Main_menu():
#     i = int(input("==> "))
#     print(" ")
    while True:
        
        print('''
          Press "1"--> Drip irrigation installation cost analysis
          Press "2"--> Products & Cost
          Press "3"--> Registration on Portal
          Press "4"--> Admin Login
          Press "ANY KEY" to exit the portal''')

        print(" ")
        enter = int(input("==> "))
        #print("You have successfully exited the portal")

        if enter ==1:
            registration()
 
        elif enter ==2:
             drip()
        
        elif enter ==3:
            inventory()
  
        elif enter == 4:
        
            admin()
                    
            
print("----------------------- DRIP IRRIGATION CONSULTANCY-----------------------")
print(" ")
print(" ")
print("Press any key to enter")
i = input("==> ")
print(" ")
print('''
Press "1"--> Drip irrigation installation cost analysis
Press "2"--> Products & Cost
Press "3"--> Registration on Portal
Press "4"--> Admin Login
Press "ANY KEY" to exit the portal''')

print(" ")
enter = int(input("==> "))
#print("You have successfully exited the portal")

if enter ==1:
 drip()
 
if enter ==2:
 inventory()
        
elif enter ==3:
  registration()
  
elif enter == 4:
 admin()
